# %%
import pandas as pd

# %%
ether = pd.read_csv('./dataset/coins/coin_Ethereum.csv')
ether.describe()
# Out:
#                SNo         High          Low         Open        Close  \
# count  2160.000000  2160.000000  2160.000000  2160.000000  2160.000000
# mean   1080.500000   398.258568   365.592589   382.879899   383.910691
# std     623.682612   628.082281   566.611523   599.719862   601.078766
# min       1.000000     0.482988     0.420897     0.431589     0.434829
# 25%     540.750000    14.265225    13.190950    13.757600    13.819200
# 50%    1080.500000   205.124631   193.302715   198.425096   198.643691
# 75%    1620.250000   396.494561   375.146804   386.264935   386.435272
# max    2160.000000  4362.350542  3785.848603  4174.635873  4168.701049
#
#              Volume     Marketcap
# count  2.160000e+03  2.160000e+03
# mean   7.057058e+09  4.172084e+10
# std    1.064526e+10  6.909184e+10
# min    1.021280e+05  3.221363e+07
# 25%    3.825102e+07  1.135576e+09
# 50%    2.148880e+09  2.070063e+10
# 75%    9.629136e+09  4.231010e+10
# max    8.448291e+10  4.828819e+11

# %%
ether2 = pd.read_csv('./dataset/ether/Ethereum Historical Data.csv')
ether2.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  2381.000000  2381.000000  2381.000000  2381.000000  2.381000e+03
# mean    854.959861   884.934784   820.687518   855.601764  1.258034e+07
# std    1147.176025  1183.295127  1104.921560  1147.126998  1.009168e+08
# min       6.680000     7.320000     5.860000     6.700000  0.000000e+00
# 25%     140.580000   145.710000   135.760000   140.810000  5.476800e+05
# 50%     284.000000   296.000000   272.290000   284.850000  1.415807e+06
# 75%    1198.030000  1256.130000  1109.000000  1206.670000  7.627971e+06
# max    4808.340000  4864.060000  4715.430000  4808.380000  1.792561e+09

# %%
crypto_prices = pd.read_csv('./dataset/crypto_prices/crypto_data_updated_27_august.csv')
crypto_prices.describe()
# Out:
#        Adj Close (BNB)  Volume (BNB)  Adj Close (BTC)  Volume (BTC)  \
# count      1753.000000  1.753000e+03      1753.000000  1.753000e+03
# mean        137.233499  9.678428e+08     20224.481952  2.574438e+10
# std         185.562414  1.477115e+09     17394.840716  1.992131e+10
# min           1.510360  9.284000e+03      3236.761719  2.923670e+09
# 25%          13.727642  1.215110e+08      7494.169922  9.926540e+09
# 50%          22.393307  3.214369e+08     10370.820313  2.327626e+10
# 75%         294.490295  1.463703e+09     35030.250000  3.511636e+10
# max         675.684082  1.798295e+10     67566.828125  3.509679e+11
#
#        Adj Close (USDT)  Volume (USDT)  Adj Close (ETH)  Volume (ETH)
# count       1753.000000   1.753000e+03      1753.000000  1.753000e+03
# mean           1.001696   4.097497e+10      1113.976655  1.295311e+10
# std            0.005891   3.889983e+10      1227.649857  1.100046e+10
# min            0.966644   3.581880e+08        84.308296  6.217330e+08
# ...

# %%
# convert date to type datetime
ether2['Date'] = pd.to_datetime(ether2['Date'])

# %%
ether2.plot(x='Date', y=['Close'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ether2.plot(x='Date', y='Volume')
